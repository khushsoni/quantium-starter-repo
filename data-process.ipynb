# %%
import pandas as pd
from glob import glob

# %%
df = sorted(glob(r'C:\Users\khush\OneDrive\Documents\GitHub\quantium-starter-repo\data\daily_sales_data*.csv'))
df
# Out:
# ['C:\\Users\\khush\\OneDrive\\Documents\\GitHub\\quantium-starter-repo\\data\\daily_sales_data_0.csv',
#  'C:\\Users\\khush\\OneDrive\\Documents\\GitHub\\quantium-starter-repo\\data\\daily_sales_data_1.csv',
#  'C:\\Users\\khush\\OneDrive\\Documents\\GitHub\\quantium-starter-repo\\data\\daily_sales_data_2.csv']

# %%
singledata = pd.concat(pd.read_csv(datafile).assign(sourcefilename = datafile)
                      for datafile in df)

# %%
singledata
# Out:
#                 product  price  quantity        date region  \
# 0           pink morsel  $3.00       546  2018-02-06  north
# 1           pink morsel  $3.00       549  2018-02-06  south
# 2           pink morsel  $3.00       577  2018-02-06   east
# 3           pink morsel  $3.00       519  2018-02-06   west
# 4           gold morsel  $9.99       580  2018-02-06  north
# ...                 ...    ...       ...         ...    ...
# 13715  vermilion morsel  $4.99       475  2022-02-14   west
# 13716      lapis morsel  $1.99       425  2022-02-14  north
# 13717      lapis morsel  $1.99       454  2022-02-14  south
# 13718      lapis morsel  $1.99       483  2022-02-14   east
# 13719      lapis morsel  $1.99       427  2022-02-14   west
#
#                                           sourcefilename
# 0      C:\Users\khush\OneDrive\Documents\GitHub\quant...
# 1      C:\Users\khush\OneDrive\Documents\GitHub\quant...
# 2      C:\Users\khush\OneDrive\Documents\GitHub\quant...
# ...

# %%
singledata.to_csv(r'C:\Users\khush\OneDrive\Documents\GitHub\quantium-starter-repo\data\single.csv')

# %%
singledata.drop(['sourcefilename'], axis = 1, inplace = True)

# %%
singledata.head()
# Out:
#        product  price  quantity        date region
# 0  pink morsel  $3.00       546  2018-02-06  north
# 1  pink morsel  $3.00       549  2018-02-06  south
# 2  pink morsel  $3.00       577  2018-02-06   east
# 3  pink morsel  $3.00       519  2018-02-06   west
# 4  gold morsel  $9.99       580  2018-02-06  north

# %%
 singledata.drop(singledata.index[(singledata["product"] != "pink morsel")], axis = 0, inplace = True)

# %%
singledata.head()
# Out:
#         product  price  quantity        date region
# 0   pink morsel  $3.00       546  2018-02-06  north
# 1   pink morsel  $3.00       549  2018-02-06  south
# 2   pink morsel  $3.00       577  2018-02-06   east
# 3   pink morsel  $3.00       519  2018-02-06   west
# 28  pink morsel  $3.00       529  2018-02-07  north

# %%
print(singledata['price'].dtype)
# Out:
# object

# %%
singledata.head()
# Out:
#         product  price  quantity        date region
# 0   pink morsel  $3.00       546  2018-02-06  north
# 1   pink morsel  $3.00       549  2018-02-06  south
# 2   pink morsel  $3.00       577  2018-02-06   east
# 3   pink morsel  $3.00       519  2018-02-06   west
# 28  pink morsel  $3.00       529  2018-02-07  north

# %%
singledata['price'] = singledata['price'].str.replace('$','').str.replace(',','')
singledata['price'] = pd.to_numeric(singledata['price'])

# %%
singledata.head()
# Out:
#         product  price  quantity        date region
# 0   pink morsel    3.0       546  2018-02-06  north
# 1   pink morsel    3.0       549  2018-02-06  south
# 2   pink morsel    3.0       577  2018-02-06   east
# 3   pink morsel    3.0       519  2018-02-06   west
# 28  pink morsel    3.0       529  2018-02-07  north

# %%
print(singledata['price'].dtype)
# Out:
# float64

# %%
singledata['sales'] = singledata['price'] * singledata['quantity']

# %%
singledata.head()
# Out:
#         product  price  quantity        date region   sales
# 0   pink morsel    3.0       546  2018-02-06  north  1638.0
# 1   pink morsel    3.0       549  2018-02-06  south  1647.0
# 2   pink morsel    3.0       577  2018-02-06   east  1731.0
# 3   pink morsel    3.0       519  2018-02-06   west  1557.0
# 28  pink morsel    3.0       529  2018-02-07  north  1587.0

# %%
singledata.drop(['price','quantity'], axis = 1, inplace = True)

# %%
singledata.head()
# Out:
#         product        date region   sales
# 0   pink morsel  2018-02-06  north  1638.0
# 1   pink morsel  2018-02-06  south  1647.0
# 2   pink morsel  2018-02-06   east  1731.0
# 3   pink morsel  2018-02-06   west  1557.0
# 28  pink morsel  2018-02-07  north  1587.0

# %%
singledata.drop(['product'], axis = 1, inplace = True)

# %%
singledata
# Out:
#              date region   sales
# 0      2018-02-06  north  1638.0
# 1      2018-02-06  south  1647.0
# 2      2018-02-06   east  1731.0
# 3      2018-02-06   west  1557.0
# 28     2018-02-07  north  1587.0
# ...           ...    ...     ...
# 13667  2022-02-13   west  2390.0
# 13692  2022-02-14  north  2035.0
# 13693  2022-02-14  south  2465.0
# 13694  2022-02-14   east  2500.0
# 13695  2022-02-14   west  2115.0
#
# [5880 rows x 3 columns]
